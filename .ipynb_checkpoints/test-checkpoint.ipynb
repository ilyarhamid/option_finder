# %%
# %load_ext autoreload
# %autoreload 2
from screener import screener
import time

# %%
param_dic = {
    "vol_window": 20,
    "RSI_window": 21,
    "RSI_ave": 9,
    "RSI_hi": 80,
    "RSI_lo": 20,
    "Stochastic": (14, 3, 6),
    "Stoch_hi": 80,
    "Stoch_lo": 20,
    "ADX_window": 14
}

path = "./ticker.xlsx"

# %%
t1 = time.time()
df = screener(path, param_dic, limit=20)
time.time() - t1
# Out:
# 1/500: CSCO
# 2/500: UAL
# 3/500: TROW
# 4/500: ISRG
# 5/500: NVR
# 6/500: PRGO
# 7/500: TPR
# 8/500: DVN
# 9/500: CE
# 10/500: MRO
# 11/500: BA
# 12/500: VRTX
# 13/500: GILD
# 14/500: NLSN
# 15/500: EQIX
# 16/500: TIF
# 17/500: MDT
# 18/500: V
# 19/500: QRVO
# 20/500: A
# 5.078073024749756

# %%
df
# Out:
#         Open     High      Low   Close    Volume Volume_above_ave      RSI  \
# CSCO   46.98    47.08    46.21   46.28  13970000            False  52.0065
# UAL    32.27    34.04    32.27   33.46  41599000            False  49.8523
# TROW  134.76   134.87   132.86  133.93   1011400            False  61.1129
# ISRG     680      685   674.25  679.69    429500            False  67.6866
# NVR   3931.5  3936.96  3778.08  3787.8     27800             True  63.1943
# PRGO   56.68    57.03    56.05    56.1    707300            False  52.8144
# TPR    13.59    13.93    13.48   13.51   4943800            False  48.5698
# DVN    10.36    10.68    10.31   10.34   5852100            False  44.6689
# CE     94.48    95.53    92.44   93.23   1260600             True  56.3672
# MRO     5.54     5.69     5.52    5.53  14626900            False  46.5833
# BA     168.5   173.74   168.23  170.84  25310700            False  47.9166
# ...
